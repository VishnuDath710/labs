# %%
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"/content/drive/MyDrive/dsspam.csv",encoding="'latin1'")
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'], inplace=True)
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data.rename(columns={'v1':'class','v2':'text'},inplace=True)
data.head()
# Out:
#   class                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   5572 non-null   object
#  1   text    5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
data.describe()
# Out:
#        class                    text
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
data.shape
# Out:
# (5572, 2)

# %%
data.isnull().any()
# Out:
# class    False
# text     False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# class    0
# text     0
# dtype: int64

# %%
data['class'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: class, dtype: int64

# %%
plt.pie(data['class'].value_counts(),labels=['ham','spam'], autopct='%0.2f')
plt.show()

# %%
sns.countplot(x = 'class', data = data)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
label_Encoder = LabelEncoder()
data['class']=label_Encoder.fit_transform(data['class'])
data.head()
# Out:
#    class                                               text
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
import string
string.punctuation
from nltk.stem.porter import PorterStemmer
import regex as re
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data.head()
# Out:
#    class                                               text
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
Transformed_text=[]
for i in range(0,5572):
  text=data["text"][i]

# %%
text=re.sub('[^a-zA-Z]',' ',text)

# %%
text=text.lower()

# %%
text=text.split()

# %%
ps=PorterStemmer()
text=[ps.stem(word) for word in text if not word in set(stopwords.words('english'))]

# %%
text=' '.join(text)
data.iloc[i,1]=text
data
# Out:
#       class                                               text
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      0              Will Ì_ b going to esplanade fr home?
# 5569      0  Pity, * was in mood for that. So...any other s...
# 5570      0  The guy did some bitching but I acted like i'd...
# 5571      0                        r o f l   t r u e   n a m e
#
# [5572 rows x 2 columns]

# %%
X = data['text']
Y = data['class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.1, random_state = 2,stratify = Y)

# %%
from tqdm import tqdm
words_in_sent = []
for i in tqdm(x_train):
  words_in_sent.append(i.split())
# Out:
# 100%|██████████| 5014/5014 [00:00<00:00, 178115.20it/s]

# %%
print(words_in_sent)
# Out:
# [['Yo', 'carlos,', 'a', 'few', 'friends', 'are', 'already', 'asking', 'me', 'about', 'you,', 'you', 'working', 'at', 'all', 'this', 'weekend?'], ['I', 'anything', 'lor.'], ['Or', 'better', 'still', 'can', 'you', 'catch', 'her', 'and', 'let', 'ask', 'her', 'if', 'she', 'can', 'sell', '&lt;#&gt;', 'for', 'me.'], ['At', '7', 'we', 'will', 'go', 'ok', 'na.'], ['Freemsg:', '1-month', 'unlimited', 'free', 'calls!', 'Activate', 'SmartCall', 'Txt:', 'CALL', 'to', 'No:', '68866.', 'Subscriptn3gbp/wk', 'unlimited', 'calls', 'Help:', '08448714184', 'Stop?txt', 'stop', 'landlineonly'], ['You', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'], ['Got', 'smaller', 'capacity', 'one?', 'Quite', 'ex...'], ['Those', 'were', 'my', 'exact', 'intentions'], ['Today', 'is', '\\song', 'dedicated', 'day..\\"', 'Which', 'song', 'will', 'u', 'dedicate', 'for', 'me?', 'Send', 'this', 'to', 'all', 'ur', 'valuable', 'frnds', 'but', 'first', 'rply', 'me..."'], ['Oh', 'unintentionally', 'not', 'bad', 'timing.', 'Great.', 'Fingers', 'the', 'trains', 'play', 'along!', 'Will', 'give', 'fifteen', 'min', 'warning.'], ['My', 'birthday', 'is', 'on', 'feb', '&lt;#&gt;', 'da.', '.'], ['Here', 'got', 'ur', 'favorite', 'oyster...', 'N', 'got', 'my', 'favorite', 'sashimi...', 'Ok', 'lar', 'i', 'dun', 'say', 'already...', 'Wait', 'ur', 'stomach', 'start', 'rumbling...'], ['Thanx.', 'Yup', 'we', 'coming', 'back', 'on', 'sun.', 'Finish', 'dinner', 'going', 'back', '2', 'hotel', 'now.', 'Time', 'flies,', "we're", 'tog', '4', 'exactly', 'a', 'mth', 'today.', 'Hope', "we'll", 'haf', 'many', 'more', 'mths', 'to', 'come...'], ['Oh,', 'i', 'will', 'get', 'paid.', 'The', 'most', 'outstanding', 'one', 'is', 'for', 'a', 'commercial', 'i', 'did', 'for', 'Hasbro...in', 'AUGUST!', 'They', 'made', 'us', 'jump', 'through', 'so', 'many', 'hoops', 'to', 'get', 'paid.', 'Still', 'not.'], ['Thanks', 'a', 'lot', 'for', 'your', 'wishes', 'on', 'my', 'birthday.', 'Thanks', 'you', 'for', 'making', 'my', 'birthday', 'truly', 'memorable.'], ['Can', 'you', 'please', 'send', 'me', 'my', "aunty's", 'number'], ['I', 'am', 'on', 'the', 'way', 'to', 'ur', 'home'], ['Aiya', 'we', 'discuss', 'later', 'lar...', 'Pick', 'Ì_', 'up', 'at', '4', 'is', 'it?'], ['Tmr', 'timin', 'still', 'da', 'same', 'wat', 'cos', 'i', 'got', 'lesson', 'until', '6...'], ['Why', 'do', 'you', 'ask', 'princess?'], ['Congratulations!', 'Thanks', 'to', 'a', 'good', 'friend', 'U', 'have', 'WON', 'the', 'å£2,000', 'Xmas', 'prize.', '2', 'claim', 'is', 'easy,', 'just', 'call', '08718726971', 'NOW!', 'Only', '10p', 'per', 'minute.', 'BT-national-rate.'], ['Hey', 'now', 'am', 'free', 'you', 'can', 'call', 'me.'], ['Think', 'I', 'could', 'stop', 'by', 'in', 'like', 'an', 'hour', 'or', 'so?', 'My', "roommate's", 'looking', 'to', 'stock', 'up', 'for', 'a', 'trip'], ['URGENT!', 'Your', 'Mobile', 'No', 'was', 'awarded', 'a', 'å£2,000', 'Bonus', 'Caller', 'Prize', 'on', '1/08/03!', 'This', 'is', 'our', '2nd', 'attempt', 'to', 'contact', 'YOU!', 'Call', '0871-4719-523', 'BOX95QU', 'BT', 'National', 'Rate'], ['Collect', 'your', "VALENTINE'S", 'weekend', 'to', 'PARIS', 'inc', 'Flight', '&', 'Hotel', '+', 'å£200', 'Prize', 'guaranteed!', 'Text:', 'PARIS', 'to', 'No:', '69101.', 'www.rtf.sphosting.com'], ['This', 'is', 'the', '2nd', 'attempt', 'to', 'contract', 'U,', 'you', 'have', 'won', 'this', 'weeks', 'top', 'prize', 'of', 'either', 'å£1000', 'cash', 'or', 'å£200', 'prize.', 'Just', 'call', '09066361921'], ['Wake', 'me', 'up', 'at', '&lt;#&gt;', 'am', 'morning:)'], ['But', 'pls', 'dont', 'play', 'in', 'others', 'life.'], ['Good', 'afternoon,', 'my', 'love.', 'It', 'was', 'good', 'to', 'see', 'your', 'words', 'on', 'YM', 'and', 'get', 'your', 'tm.', 'Very', 'smart', 'move,', 'my', 'slave', '...', '*smiles*', '...', 'I', 'drink', 'my', 'coffee', 'and', 'await', 'you.'], ['Hey!', "There's", 'veggie', 'pizza...', ':/'], ['I', 'was', 'just', 'callin', 'to', 'say', 'hi.', 'Take', 'care', 'bruv!'], ['Good', 'evening!', 'this', 'is', 'roger.', ' ...

# %%
from gensim.models import Word2Vec, FastText
word2vec_model = Word2Vec(sentences = words_in_sent,vector_size = 300,window = 5, workers = 2)
word2vec_model

# %%
vocabulary = word2vec_model.wv.key_to_index
print(vocabulary)
# Out:
# {'to': 0, 'you': 1, 'I': 2, 'a': 3, 'the': 4, 'and': 5, 'in': 6, 'is': 7, 'i': 8, 'u': 9, 'for': 10, 'my': 11, 'of': 12, 'your': 13, 'me': 14, 'on': 15, 'have': 16, '2': 17, 'that': 18, 'it': 19, 'are': 20, 'or': 21, 'call': 22, 'be': 23, 'at': 24, 'not': 25, 'with': 26, 'will': 27, 'get': 28, 'so': 29, 'can': 30, 'U': 31, 'ur': 32, "I'm": 33, 'but': 34, '&lt;#&gt;': 35, 'You': 36, 'from': 37, 'do': 38, '4': 39, 'up': 40, 'if': 41, 'go': 42, '.': 43, 'just': 44, 'this': 45, 'when': 46, 'like': 47, 'know': 48, 'we': 49, 'all': 50, 'out': 51, 'got': 52, 'was': 53, 'come': 54, 'now': 55, 'am': 56, '?': 57, '...': 58, 'Call': 59, 'by': 60, 'want': 61, 'time': 62, 'about': 63, 'going': 64, 'send': 65, 'then': 66, 'only': 67, 'need': 68, 'n': 69, 'what': 70, 'one': 71, 'How': 72, "I'll": 73, 'still': 74, 'If': 75, 'But': 76, 'text': 77, 'no': 78, 'its': 79, 'he': 80, 'No': 81, 'been': 82, 'think': 83, 'our': 84, 'as': 85, 'Just': 86, 'We': 87, 'So': 88, 'how': 89, 'some': 90, 'has': 91, 'good': 92, 'there': 93, 'love': 94, 'any': 95, 'see': 96, "don't": 97, 'r': 98, '&': 99, 'Ì_': 100, 'back': 101, 'tell': 102, 'Your': 103, 'Do': 104, 'take': 105, 'home': 106, 'day': 107, 'an': 108, 'And': 109, 'What': 110, 'My': 111, 'her': 112, 'free': 113, 'The': 114, 'Ok': 115, 'they': 116, 'me.': 117, 'dont': 118, 'him': 119, 'FREE': 120, "i'm": 121, 'mobile': 122, 'who': 123, 'new': 124, 'phone': 125, 'she': 126, '-': 127, 'make': 128, 'now.': 129, 'more': 130, 'give': 131, 'ask': 132, 'later': 133, 'Have': 134, 'A': 135, 'you.': 136, 'd': 137, '&amp;': 138, 'To': 139, 'Can': 140, 'much': 141, 'This': 142, 'Are': 143, 'had': 144, 'da': 145, 'Hey': 146, 'reply': 147, 'txt': 148, 'great': 149, 'meet': 150, 'here': 151, 'way': 152, 'after': 153, 'Good': 154, 'should': 155, 'Its': 156, 'them': 157, 'week': 158, 'say': 159, 'e': 160, 'lor.': 161, 'would': 162, 'Txt': 163, 'very': 164, 'claim': 165, 'too': 166, 'contact': 167, 'pick': 168, 'number': 169, 'really': 170, 'said': 171, 'find': 172, 'did': 173, '1': 174, 'every': 175, 'work': 176, 'stop': 177, 'night': 178, 'ok': 179, 'Pls': 180, 'Oh': 181, 'next': 182, 'doing': 183, 'Please': 184, 'where': 185, 'last': 186, 'message': 187, 'right': 188, 'Hi': 189, 'miss': 190, 'keep': 191, 'Ur': 192, 'sent': 193, 'It': 194, 'feel': 195, '!': 196, 'Then': 197, 'gonna': 198, 'per': 199, ':)': 200, 'could': 201, 'told': 202, 'sure': 203, 'it.': 204, 'many': 205, 'cos': 206, 'Not': 207, 'lor...': 208, 'let': 209, 'hope': 210, 'went': 211, 'wan': 212, 'buy': 213, 'ÌÏ': 214, 'b': 215, 'cant': 216, 'cash': 217, 'around': 218, 'today': 219, 'msg': 220, "it's": 221, 'now!': 222, 'He': 223, 'other': 224, 'Happy': 225, 'Sorry': 226, 'Sorry,': 227, 'tomorrow': 228, 'please': 229, 'Is': 230, 'us': 231, 'Did': 232, 'leave': 233, 'were': 234, 'Lol': 235, 'Reply': 236, '3': 237, 'also': 238, 'When': 239, 'day.': 240, "can't": 241, 'why': 242, 'before': 243, 'c': 244, 'already': 245, 'Nokia': 246, 'dun': 247, 'even': 248, 'his': 249, 'Dear': 250, 'down': 251, 'something': 252, 'service': 253, 'getting': 254, 'few': 255, 'someone': 256, 'Get': 257, 'which': 258, 'always': 259, 'STOP': 260, 'prize': 261, 'Hope': 262, 'anything': 263, 'things': 264, 'waiting': 265, 'won': 266, 'being': 267, 'place': 268, 'thing': 269, 'Yeah': 270, 'wait': 271, 'trying': 272, 'coming': 273, 'people': 274, 'care': 275, 'first': 276, "you're": 277, 'Where': 278, 'over': 279, 'late': 280, 'money': 281, 'Text': 282, 'Thanks': 283, 'R': 284, 'having': 285, "didn't": 286, 'Will': 287, 'use': 288, 'For': 289, "I've": 290, 'She': 291, 'well': 292, 'As': 293, "It's": 294, 'Or': 295, '1st': 296, 'off': 297, 'thk': 298, 'happy': 299, 'awarded': 300, 'shows': 301, 'finish': 302, 'Free': 303, 'Yes': 304, 'win': 305, 'morning': 306, 'hi': 307, '*': 308, 'im': 309, 'draw': 310, 'pls': 311, 'sleep': 312, 'thought': 313, 'Now': 314, 'In': 315, 'å£1000': 316, 'They': 317, 'try': 318, 'x': 319, 'wat': 320, 'bit': 321, 'than': 322, 'life': 323, 'you,': 324, 'b ...

# %%
len(vocabulary)
# Out:
# 2066

# %%
v1 = word2vec_model.wv['around']
v1
# Out:
# array([-1.72177120e-03,  1.90669417e-01, -1.62046365e-02,  6.79566860e-02,
#         5.27153239e-02, -2.75964588e-01,  1.62844330e-01,  4.07317758e-01,
#         1.34468591e-02, -1.00452423e-01,  7.67252445e-02, -1.64166048e-01,
#        -6.47062808e-02,  3.07080951e-02, -1.50715590e-01, -5.36793694e-02,
#         1.69782713e-01, -4.95732576e-02,  3.58296186e-03, -8.80555660e-02,
#        -7.87467584e-02, -6.98792189e-02,  1.50106877e-01,  9.26417578e-03,
#         1.66832179e-01, -6.87141418e-02, -2.15403244e-01, -4.20211116e-03,
#        -1.38735905e-01, -2.16909140e-01,  1.24334179e-01, -8.74085128e-02,
#         5.46522401e-02,  4.68495376e-02, -3.54846343e-02,  7.92028606e-02,
#         1.11603446e-01, -2.02083841e-01, -1.41287148e-02, -1.95235591e-02,
#        -5.54720797e-02,  4.26512808e-02,  5.02713434e-02, -1.96300611e-01,
#         1.01572521e-01,  1.82799771e-01,  5.27898073e-02,  8.57652724e-02,
#        -3.78057198e-03,  1.92809865e-01,  6.31129369e-02,  3.44850160e-02,
#        -1.13132678e-01,  8.76841247e-02, -4.55735438e-03,  2.26551175e-01,
#         1.23787679e-01,  6.33360818e-02, -4.94219130e-03,  1.76204480e-02,
#        -5.97098134e-02, -8.09300691e-02,  2.06090845e-02,  7.66756460e-02,
#         2.94125713e-02,  8.94785225e-02, -2.30510700e-02,  9.72004700e-03,
#        -1.16504475e-01, -1.30262887e-02, -4.14816141e-02,  6.83024973e-02,
#         1.83035940e-01, -2.34609574e-01,  4.20164317e-02,  9.07936692e-02,
#        -1.25887379e-01, -2.27976944e-02, -3.39607634e-02,  1.32122368e-01,
#        -8.14570412e-02, -1.52688041e-01,  2.36249040e-03,  3.59950989e-01,
#         9.00344402e-02,  8.62462446e-03, -1.20726921e-01, -2.93143429e-02,
#         1.74359992e-01,  6.26766309e-02,  1.52368605e-01, -1.56274855e-01,
#         6.58822209e-02,  2.38140672e-02,  2.19367012e-01,  1.20862588e-01,
#         1.20565921e-01, -7.14845955e-02, -8.35514441e-02,  8.37384835e-02,
#        -9.82340891e-03, -1.57634600e-03,  1.40048429e-01,  4.28085029e-03,
#        -2.71620210e-02, -2.52227426e-01, -3.13075930e-02,  3.75306755e-02,
#        -1.75330043e-01,  6.68679774e-02, -1.73517868e-01, -1.52288452e-01,
#         7.85798952e-02,  2.03345150e-01,  6.76615760e-02,  9.06836987e-02,
#         2.05826964e-02, -2.63752397e-02,  1.78160340e-01, -2.16454595e-01,
#         7.62254223e-02,  8.57955590e-02,  1.15730308e-01, -6.29646406e-02,
#        -1.10678747e-01,  7.33622611e-02,  8.07920098e-02, -1.65353790e-01,
#        -2.46389415e-02,  1.06502138e-01,  5.02899997e-02,  1.86627716e-01,
#         5.59138432e-02, -2.26968408e-01,  6.64780438e-02,  8.00721645e-02,
#        -7.91157261e-02, -1.40767843e-01, -1.91063926e-01, -1.71750724e-01,
#         2.54605468e-02, -2.34571368e-01, -6.21219873e-02,  1.33717924e-01,
#         9.76168066e-02, -9.68190730e-02, -2.78706312e-01, -6.81923106e-02,
#         8.22116062e-02, -8.79338607e-02,  4.71240953e-02, -3.14063281e-01,
#        -1.75242543e-01, -1.15851767e-01, -6.26318827e-02,  6.97742626e-02,
#        -1.85182795e-01, -7.44278580e-02, -3.39087658e-02,  2.16388062e-01,
#         2.98825800e-02,  1.14136577e-01, -2.27078781e-01,  1.78477228e-01,
#        -2.05954000e-01,  1.13033444e-01, -5.70939062e-03, -6.97923750e-02,
#         5.77308461e-02,  2.87795275e-01, -1.08778358e-01, -3.41468640e-02,
#         6.28345311e-02,  1.22328393e-01, -9.11178906e-03,  6.81820437e-02,
#        -6.08203374e-02, -2.24409342e-01,  5.88780828e-02,  2.71646958e-02,
#        -7.35024214e-02,  1.64572462e-01, -1.86272457e-01, -4.88842502e-02,
#        -6.54655546e-02,  7.69717768e-02,  3.10567826e-01,  2.33859882e-01,
#         6.11723587e-02, -1.74833432e-01, -2.08773948e-02,  4.04414795e-02,
#        -2.12326974e-01, -4.24282998e-02,  7.57235065e-02, -1.54028907e-01,
#         2.65175458e-02, -2.23246455e-01,  6.53681532e-02, -5.72690777e-02,
#        -2.08558396e-01,  5.19487495e-03, -5.70448339e-02, -1.07779071e-01,
#         1.34560037e-02, -5.22258244e-02, -2.21910216e-02,  8.80652666e-02,
#        -6.17893897e-02, -6.08603507e-02,  1.41649056e-04, -1.34607196e-01,
#        -1.24965511e-01, -1.15953930e-01,  7.71651119e-02, -1.62697405e-01,
#        -1.64200976e-01, -3.71561557e-01, -2.40599826e-01, -1.53962314e-01,
#         1.41805395e-01,  4.83752042e-03, -8.11979026e-02, -1.77018985e-01,
#        -7.92747289e-02, -8.93322378e-02,  3.86037938e-02, -2.04248801e-02,
#        -1.90355778e-01,  4.12830412e-02,  1.32815033e-01, -5.60918041e-02,
#        -5.88801093e-02,  1.55297950e-01, -1.23357140e-01,  5.94590195e-02,
#        -3.14613506e-02,  5.72669506e-02,  5.91132231e-02, -2.77952462e-01,
#         2.69647595e-03, -7.33726472e-02, -1.04513839e-01, -1.97467562e-02,
#         5.28798858e-03, -2.67946333e-01, -2.91789938e-02,  4.89011109e-02,
#         1.29281741e-03,  1.08185060e-01,  4.19245102e-02,  3.23453881e-02,
#         9.94585305e-02, -1.45932625e-03, -2.47320980e-01, -8.91140550e-02,
#         2.34858140e-01,  2.95798257e-02, -2.57621884e-01, -1.55845121e-01,
#         1.12986378e-01,  8.39681327e-02,  1.07796654e-01, -2.50517070e-01,
#        -2.60703921e-01,  1.08766928e-02,  1.14722610e-01,  1.33030146e-01,
#        -2.15533555e-01,  5.50686643e-02, -1.22685887e-01,  2.09989566e-02,
#         2.86650266e-02, -6.93339631e-02,  1.99456155e-01,  5.09584174e-02,
#         1.60131469e-01,  7.96454679e-03, -2.41571859e-01, -4.88357954e-02,
#         1.83380514e-01, -4.02627252e-02, -1.24781057e-01,  1.55730620e-01,
#         3.49731855e-02, -8.36544260e-02, -2.80291826e-01,  9.56569836e-02,
#         6.20939881e-02,  2.17362568e-01,  4.05512303e-02,  2.47097716e-01,
#         1.67293638e-01,  7.21581951e-02,  2.50892341e-01,  2.89985776e-01,
#        -1.50873195e-02, -9.41648558e-02,  1.49736375e-01, -7.48589411e-02],
#       dtype=float32)

# %%
sim_words = word2vec_model.wv.most_similar('free')
sim_words
# Out:
# [('from', 0.9998795390129089),
#  ('or', 0.9998775720596313),
#  ('our', 0.9998741149902344),
#  ('mobile', 0.999870777130127),
#  ('-', 0.9998698830604553),
#  ('now!', 0.9998698830604553),
#  ('To', 0.9998677372932434),
#  ('&', 0.9998641014099121),
#  ('U', 0.9998630285263062),
#  ('Just', 0.9998605847358704)]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
def plot_word_embeddings(word2vec_model):
  words = word2vec_model.wv.index_to_key
  X = word2vec_model.wv[words]
  pca = PCA(n_components=2)
  result = pca.fit_transform(X)

  df = pd.DataFrame(result, index=words, columns=['x', 'y'])
  print(df.head())
  plt.figure(figsize=(10, 6))
  plt.scatter(df['x'], df['y'])
  for word, pos in df.iterrows():
    plt.annotate(word, pos)
  plt.xlabel('Principal Component 1')
  plt.ylabel('Principal Component 2')
  plt.title('Email Word Embeddings Visualization')
  plt.show()
plot_word_embeddings(word2vec_model)
# Out:
#             x         y
# to   3.020740 -0.038047
# you  2.885906 -0.047951
# I    3.317582 -0.019053
# a    3.104646 -0.027633
# the  2.973945 -0.007147
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 137 (\x89) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
